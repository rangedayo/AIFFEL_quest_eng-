# %% [markdown]
# <a href="https://colab.research.google.com/github/leeaain2027/AIFFEL_quest_eng/blob/main/Python/Py03/Sub_Quest_C_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 사용자로부터 두 개의 정수와 연산자(+,-,*,/,**)를 입력받아 계산 결과를 출력하는 프로그램을 만들어주세요
#
#
#  조건
# 사용자가 입력한 값이 정수가 아닌 경우 ValueError를 처리하여 적절한 오류 메시지를 출력해야 합니다
# 정수가 입력될 때 까지 “잘못된 입력입니다. 정수를 입력해주세요.”를 출력하며 다시 입력받기를 시도합니다.
# 나눗셈 연산 시 두 번째 정수가 0인 경우 ZeroDivisionError를 처리하여 적절한 오류 메시지를 출력합니다.
# 사용자가 지원하지 않는 연산자를 입력한 경우 적절한 오류 메시지를 출력합니다.
# math 모듈을 사용하여 제곱 연산(**)을 지원합니다.
# 계산기를 통해 계속 계산을 할 것인지 입력받습니다.

# %%
from math import pow

def calc(a, b, oper):
    result = 0

    if oper == '+':
        result = a + b

    elif oper == '-':
        result = a - b

    elif oper == '*':
        result = a * b

    elif oper == '/':
        result = a / b

    elif oper == '**':
        result = math.pow(a, b)

    else:
        raise Exception

  return result

# %%
while(True):
    try:
        # 입력
        # str_a와 a가 응집도가 높은 것을 보여줌. 유지보수를 위해서. (변화에는 열려있고 수정에는 닫혀있다)
        str_a = input('첫번째 정수를 입력하세요: ')    # 첫번째 정수
        a = 0    # 명시적으로 보여주려고
        if str_a.isdigit():
            a = int(str_a)
        else:
            raise ValueError

        str_b = input('두번째 정수를 입력하세요: ')    # 두번째 정수
        b = 0
        if str_b.isdigit():
            b = int(str_b)
        else:
            raise ValueError

        oper = input('연산자를 입력하세요: ') # 연산자
        result = calc(a, b, oper)

    except ZeroDivisionError as zde:
        print("0으로 나눌 수 없습니다.")
    except ValueError as ve:
        print("정수가 아닙니다.")
    except Exception as e:
        print("적절한 연산자 또는 오류가 발생하였습니다.")
    else:
        print(result)
# Out:
# 첫번째 정수를 입력하세요: 1
# 두번째 정수를 입력하세요: b
# 정수가 아닙니다.
# 첫번째 정수를 입력하세요: 1
# 두번째 정수를 입력하세요: 2
# 연산자를 입력하세요: +
# 3
# 첫번째 정수를 입력하세요: 4
# 두번째 정수를 입력하세요:
# 정수가 아닙니다.
# 첫번째 정수를 입력하세요: 4
# 두번째 정수를 입력하세요: 2
# 연산자를 입력하세요: /
# 2.0
# 첫번째 정수를 입력하세요: 4
# 두번째 정수를 입력하세요: 0
# 연산자를 입력하세요: /
# 0으로 나눌 수 없습니다.
# 첫번째 정수를 입력하세요: 2
# 두번째 정수를 입력하세요: 2
# 연산자를 입력하세요: //
# 적절한 연산자 또는 오류가 발생하였습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-778740111.py in <cell line: 0>()
#       2     try:
#       3         # 입력
# ----> 4         str_a = input('첫번째 정수를 입력하세요: ')    # 첫번째 정수
#       5         a = 0
#       6         if str_a.isdigit():
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# ...

# %%
while True:
    try:
        a = int(input('첫번째 정수를 입력하세요: ')) # 'a' -> 에러 남
    except:
        print('정수가 아닙니다.')
    else: # int()에러가 안났음. 숫자가 제대로 입력이 됏음.
        break # while을 탈출하기

# 다음 while
while True:
    try:
        b = int(input('두번째 정수'))
    except:
        print('정수가 아닙니다.')
    else:
        break
# Out:
# 2

# %%
import math as m
math.pow(2, 3)
ㅡㅁㅇ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1878515516.py in <cell line: 0>()
#       1 import math as m
# ----> 2 math.pow(2, 3)
#       3 ㅡㅁㅇ
#
# NameError: name 'math' is not defined
